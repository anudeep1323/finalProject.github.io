# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc4b4602-420c-4667-9568-a49a170b1edc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc4b4602-420c-4667-9568-a49a170b1edc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving housing.csv to housing.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cfe66b98-548d-4f8d-8abd-930f05e15491" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfe66b98-548d-4f8d-8abd-930f05e15491">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving california.png to california.png

# %%
import io
import pandas as pd
housing = pd.read_csv(io.BytesIO(uploaded['housing.csv']))
housing
# Out:
#        longitude  latitude  ...  median_house_value  ocean_proximity
# 0        -122.23     37.88  ...            452600.0         NEAR BAY
# 1        -122.22     37.86  ...            358500.0         NEAR BAY
# 2        -122.24     37.85  ...            352100.0         NEAR BAY
# 3        -122.25     37.85  ...            341300.0         NEAR BAY
# 4        -122.25     37.85  ...            342200.0         NEAR BAY
# ...          ...       ...  ...                 ...              ...
# 20635    -121.09     39.48  ...             78100.0           INLAND
# 20636    -121.21     39.49  ...             77100.0           INLAND
# 20637    -121.22     39.43  ...             92300.0           INLAND
# 20638    -121.32     39.43  ...             84700.0           INLAND
# 20639    -121.24     39.37  ...             89400.0           INLAND
#
# [20640 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import cv2
img = cv2.imread('california.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
housing_plot = housing[['longitude', 'households','population','latitude','median_house_value', 'ocean_proximity', 'median_income', 'total_bedrooms']]

# %%
import matplotlib.pyplot as plt
housing_plot.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,
				s=housing_plot['population']/100, label='population', figsize=(10,7),
				c='median_house_value', cmap=plt.get_cmap('jet'), colorbar=True)


plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend() 
plt.show()

# %%
import matplotlib.pyplot as plt
housing_plot.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,
				s=housing_plot['population']/100, label='population', figsize=(10,7),
				c='median_income', cmap=plt.get_cmap('jet'), colorbar=True)


plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend() 
plt.show()

# %%
import matplotlib.pyplot as plt
housing_plot.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,
				s=housing_plot['population']/100, label='population', figsize=(10,7),
				c='households', cmap=plt.get_cmap('jet'), colorbar=True)


plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend() 
plt.show()

# %%
import matplotlib.pyplot as plt
housing_plot.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,
				s=housing_plot['population']/100, label='population', figsize=(10,7),
				c='total_bedrooms', cmap=plt.get_cmap('jet'), colorbar=True)


plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend() 
plt.show()

# %%
import matplotlib.pyplot as plt
housing_plot.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,
				s=housing_plot['population']/100, label='population', figsize=(10,7),
				c='longitude', cmap=plt.get_cmap('jet'), colorbar=True)


plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend() 
plt.show()

# %%
import matplotlib.pyplot as plt
housing_plot.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,
				s=housing_plot['population']/100, label='population', figsize=(10,7),
				c='latitude', cmap=plt.get_cmap('jet'), colorbar=True)


plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend() 
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d738c2b8-85d7-46ed-8103-36b320a730be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d738c2b8-85d7-46ed-8103-36b320a730be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cal_populations_county.csv to cal_populations_county (2).csv

# %%
 cal_populations_county = pd.read_csv(io.BytesIO(uploaded['cal_populations_county.csv']))
 cal_populations_county.head(5)
# Out:
#            County          City  ... pop_april_2000  pop_april_2010
# 0  San Bernardino      Adelanto  ...          18130           31765
# 1     Los Angeles  Agoura Hills  ...          20537           20330
# 2         Alameda       Alameda  ...          72259           73812
# 3         Alameda        Albany  ...          16444           18539
# 4     Los Angeles      Alhambra  ...          85804           83089
#
# [5 rows x 7 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-db86c236-0dbd-4ffa-8cf1-685ab6793fa0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db86c236-0dbd-4ffa-8cf1-685ab6793fa0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cal_populations_city.csv to cal_populations_city (2).csv

# %%
 cal_populations_city = pd.read_csv(io.BytesIO(uploaded['cal_populations_city.csv']))
 cal_populations_city.head(5)
# Out:
#            County          City  ... pop_april_2000  pop_april_2010
# 0  San Bernardino      Adelanto  ...          18130           31765
# 1     Los Angeles  Agoura Hills  ...          20537           20330
# 2         Alameda       Alameda  ...          72259           73812
# 3         Alameda        Albany  ...          16444           18539
# 4     Los Angeles      Alhambra  ...          85804           83089
#
# [5 rows x 7 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f399035f-e42f-47b0-96da-48cfe38f721e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f399035f-e42f-47b0-96da-48cfe38f721e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cal_cities_lat_long.csv to cal_cities_lat_long (2).csv

# %%
city_lat_long = pd.read_csv(io.BytesIO(uploaded['cal_cities_lat_long.csv']))
city_lat_long
# Out:
#              Name   Latitude   Longitude
# 0        Adelanto  34.582769 -117.409214
# 1    Agoura Hills  34.153339 -118.761675
# 2         Alameda  37.765206 -122.241636
# 3          Albany  37.886869 -122.297747
# 4        Alhambra  34.095286 -118.127014
# ..            ...        ...         ...
# 454      Woodland  38.678517 -121.773297
# 455   Yorba Linda  33.888625 -117.813111
# 456         Yreka  41.735419 -122.634472
# 457     Yuba City  39.140447 -121.616911
# 458       Yucaipa  34.033625 -117.043086
#
# [459 rows x 3 columns]

# %%
city_coords = {}

for dat in city_lat_long.iterrows():
    row = dat[1]
    if row['Name'] not in cal_populations_city['City'].values:   
        continue           
    else: 
        city_coords[row['Name']] = (float(row['Latitude']), float(row['Longitude']))

# %%
from geopy.distance import vincenty
def closest_point(location, location_dict):
    closest_location = None
    for city in location_dict.keys():
        distance = vincenty(location, location_dict[city]).kilometers
        if closest_location is None:
            closest_location = (city, distance)
        elif distance < closest_location[1]:
            closest_location = (city, distance)
    return closest_location
test = (39.524325, -122.293592) 
closest_point(test, city_coords)
# Out:
# ('Willows', 8.598342477208991)

# %%
city_pop_dict = {}
for dat in cal_populations_city.iterrows():
    row = dat[1]
    city_pop_dict[row['City']] =  row['pop_april_1990']

# %%
housing['close_city'] = housing.apply(lambda x: 
							closest_point((x['latitude'],x['longitude']),city_coords), axis = 1)
housing['close_city_name'] = [x[0] for x in housing['close_city'].values]
housing['close_city_dist'] = [x[1] for x in housing['close_city'].values]
housing['close_city_pop'] = [city_pop_dict[x] for x in housing['close_city_name'].values]

housing = housing.drop('close_city', axis=1)
housing.head()
# Out:
#    longitude  latitude  ...  close_city_dist  close_city_pop
# 0    -122.23     37.88  ...         3.874956          102724
# 1    -122.22     37.86  ...         4.025281           16642
# 2    -122.24     37.85  ...         2.938276           10602
# 3    -122.25     37.85  ...         3.122559          102724
# 4    -122.25     37.85  ...         3.122559          102724
#
# [5 rows x 13 columns]

# %%
housing_plot.plot(kind='scatter', x='longitude', y='latitude',  alpha=0.4,
				s=housing_plot['population']/100, label='population', figsize=(10,7))

for line in housing.iterrows():
	dat = line[1]
	x1 = dat['longitude']
	y1 = dat['latitude']
	p2 = city_coords[dat['close_city_name']]
	x2 = p2[1]
	y2 = p2[0]
	plt.plot([x1,x2],[y1, y2], 'k-',linewidth=0.1)

plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.show()

# %%
city_lat_long['Population'] = [city_pop_dict[x] if x in city_pop_dict.keys() 
												else 0 for x in city_lat_long['Name'].values]
housing.plot(kind='scatter', x='longitude', y='latitude',  alpha=0.4,
				s=housing['population']/200, label='population', figsize=(10,7))

plt.imshow(img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
plt.legend() 
plt.show()
